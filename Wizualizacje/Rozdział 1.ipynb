# %% [markdown]
# # Rysunek 1 - sfera Blocha

# %%
##### from qiskit.visualization import plot_bloch_vector, bloch
from matplotlib.pyplot import text
from math import pi, cos, sin
from qutip import *

def draw_angles_on_bloch(theta, phi):
    x = sin(theta)*cos(phi)
    y = sin(theta)*sin(phi)
    z = cos(theta)
    
    # preparing the sphere
    sphere = bloch
    sphere.Bloch
    b = Bloch()
    b.figsize = [8,8]
    b.size=[4,4]
    # preparing the lables
    b.ylpos = [1.15, -1.18]
    b.zlpos=[1.16,-1.1]
    b.xlabel = ['$Y: \\frac{\\left|0\\right>+\\left|1\\right>}{\\sqrt{2}}$'
                , '$\\frac{\\left|0\\right>-\\left|1\\right>}{\\sqrt{2}}$']

   # b.xlabel = ['Y: $\\left|0\\right>+\\left|1\\right>$', '$\\left|0\\right>-\\left|1\\right>$']
    b.ylabel = ['$X: \\frac{\\left|0\\right>+i\\left|1\\right>}{\\sqrt{2}}$',
                '$\\frac{\\left|0\\right>-i\\left|1\\right>}{\\sqrt{2}}$']
    b.zlabel = ['$Z: \\left|0\\right>$','$\\left|1\\right>$']
    # first 6 drawn vectors will be blue, the 7th - red - WSZYSTKIE BLUE
    b.vector_color = ['b','b','b','b','b','b','b']
    # drawing vectors of orthogonal states (most popular bases), note the coordinates of vectors,
    # they correspond to the according states.
    b.add_vectors([[0,0,1],[0,0,-1],[0,1,0],[0,-1,0],[1,0,0],[-1,0,0]])
    # drawing our state (as 7th vector)
    b.add_vectors([x,y,z])


    # showing the Bloch sphere with all that we have prepared
    b.font_size=15
    b.show()

    print(b)
    bb = b.fig
    bb.savefig("bloch.png")
    
    
draw_angles_on_bloch(pi/2, pi/2)
# Out:
# Bloch data:
# -----------
# Number of points:  0
# Number of vectors: 7
#
# Bloch sphere properties:
# ------------------------
# font_color:      black
# font_size:       15
# frame_alpha:     0.2
# frame_color:     gray
# frame_width:     1
# point_color:     ['b', 'r', 'g', '#CC6600']
# point_marker:    ['o', 's', 'd', '^']
# point_size:      [25, 32, 35, 45]
# sphere_alpha:    0.2
# sphere_color:    #FFDDDD
# figsize:         [8, 8]
# vector_color:    ['b', 'b', 'b', 'b', 'b', 'b', 'b']
# vector_width:    3
# vector_style:    -|>
# vector_mutation: 20
# view:            [-60, 30]
# xlabel:          ['$Y: \\frac{\\left|0\\right>+\\left|1\\right>}{\\sqrt{2}}$', '$\\frac{\\left|0\\right>-\\left|1\\right>}{\\sqrt{2}}$']
# xlpos:           [1.2, -1.2]
# ylabel:          ['$X: \\frac{\\left|0\\right>+i\\left|1\\right>}{\\sqrt{2}}$', '$\\frac{\\left|0\\right>-i\\left|1\\right>}{\\sqrt{2}}$']
# ylpos:           [1.15, -1.18]
# zlabel:          ['$Z: \\left|0\\right>$', '$\\left|1\\right>$']
# zlpos:           [1.16, -1.1]

# %% [markdown]
# # Rysunki do tabeli 1

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit, execute, Aer
from math import pi
q =  QuantumRegister(2,"qreg") # in this example we will use a single quantum bit
c = ClassicalRegister(2,"creg") # in this example we will use a single classical bit
qc = QuantumCircuit(q,c)
#qc.x(q[1])
theta= pi/6
t = '$\\theta$'
print(t)
#qc.rz(theta,q[0])
qc.measure(q,c)
#qc.s(q[2])





display(qc.draw("mpl"))
# Out:
# $\theta$
